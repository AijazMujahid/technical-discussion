# %% [markdown]
# <a href="https://colab.research.google.com/github/AijazMujahid/technical-discussion/blob/main/technical_doc1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello_world():
  print('Hello, World!')

hello_world()
# Out:
# Hello, World!

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
